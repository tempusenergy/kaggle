# %% [markdown]
# ## Combining Data...
# This notebook is an example showing how to combine the various datasets into a comprehensive train/test dataframe.
#
# Train and test are linked to the three intermediate tables by the following key columns:
#
# - cliente_tabla -> Cliente_ID
# - producto_tabla -> Producto_ID
# - town_state -> Agencia_ID

# %%
from tools.load_data import GrupoBimboData
gb = GrupoBimboData('/home/gus/Repos/kaggle/data')
gb.load_data('cliente_tabla')
gb.load_data('producto_tabla')
gb.load_data('town_state')
gb.load_data('test')
gb.load_data('train', nrows=2000)

# %%
train = gb.combine_data('train', keep_index_cols=False)
train.head()
# Out:
#    Semana  Canal_ID  Ruta_SAK  Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  \
# 0       3         7      3301              3      25.14                0
# 1       3         7      3301              3      25.14                0
# 2       3         7      3301              2      16.76                0
# 3       3         7      3301              4      33.52                0
# 4       3         7      3301              3      25.14                0
#
#    Dev_proxima  Demanda_uni_equil                 NombreCliente  \
# 0          0.0                  3   PUESTO DE PERIODICOS LAZARO
# 1          0.0                  3           PTO REV JOSE CARLOS
# 2          0.0                  2       PUESTO DE REVISTA ROMAN
# 3          0.0                  4     DULCERIA HOSPITAL ESPAÑOL
# 4          0.0                  3  PUESTO DE DULCES LIVERPOOL 2
#
#                   NombreProducto                Town         State
# 0  Roles Canela 2p 120g BIM 1212  2008 AG. LAGO FILT  MÉXICO, D.F.
# 1  Roles Canela 2p 120g BIM 1212  2008 AG. LAGO FILT  MÉXICO, D.F.
# 2  Roles Canela 2p 120g BIM 1212  2008 AG. LAGO FILT  MÉXICO, D.F.
# 3  Roles Canela 2p 120g BIM 1212  2008 AG. LAGO FILT  MÉXICO, D.F.
# 4  Roles Canela 2p 120g BIM 1212  2008 AG. LAGO FILT  MÉXICO, D.F.

# %%
test = gb.combine_data('test')
test.head()
# Out:
#         id  Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0        0      11        4037         1      2209     4639078        35305
# 1   801547      10        4037         1      2209     4639078        35305
# 2  3896339      11        4037         1      2224     4657880        35305
# 3  4561061      11        4037         1      2101      235433        35305
# 4  1847000      10        4037         1      2102      238580        35305
#
#      NombreCliente                         NombreProducto  \
# 0  NO IDENTIFICADO  Barritas Fresa 75g Prom MTB MLA 35305
# 1  NO IDENTIFICADO  Barritas Fresa 75g Prom MTB MLA 35305
# 2  NO IDENTIFICADO  Barritas Fresa 75g Prom MTB MLA 35305
# 3       MS ESTHELA  Barritas Fresa 75g Prom MTB MLA 35305
# 4            ANAIS  Barritas Fresa 75g Prom MTB MLA 35305
#
#                     Town       State
# 0  2499 REYNOSA MARINELA  TAMAULIPAS
# 1  2499 REYNOSA MARINELA  TAMAULIPAS
# 2  2499 REYNOSA MARINELA  TAMAULIPAS
# 3  2499 REYNOSA MARINELA  TAMAULIPAS
# 4  2499 REYNOSA MARINELA  TAMAULIPAS
